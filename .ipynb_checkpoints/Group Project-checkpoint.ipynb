# %% [markdown]
# ## Minecraft Player Data Analysis Project

# %% [markdown]
# ![Minecraft](https://upload.wikimedia.org/wikipedia/en/b/b6/Minecraft_2024_cover_art.png)

# %% [markdown]
# ## Introduction
# #### Background Information
# Aresearch group in Computer Science at UBC, led by Frank Wood, is collecting data about how people play video games. They record players' actions as they play through a MineCraft serverLinks to an external site.
#
# ### Question 2:
# We would like to know which "kinds" of players are most likely to contribute a large amount of data so that we can target those players in our recruiting efforts.
# ### Can age predict the hours played in this dataset?
#
# * This dataset will help indicate whether age can predict the amount of time a Minecraft user plays for. This relationship could help user engagement, refine marketing strategies, increase sales and gaming suggestions.

# %% [markdown]
# ## Players Dataset Overview:
# This dataset observes Minecraft user's gaming experience and contains information like player status, subscription, playtime, and demographics.
# * Number of observations (rows): 196
# * Number of variables (columns): 7

# %% [markdown]
# ## Columns in the Players Data Set:
# ### Numerical (dbl):
# * `played_hours` - The number of hours the user has played.
# * `Age`- the age of the player.
#
# ### Character (chr):
# * `hashedEmail`- encrypted email for user identification.
# * `name`- The name of the player.
# * `gender`- Classified as either Male, Female, Non-binary, or Prefer not to say
# * `experience`- The level of experience classified (Pro, Veteran, Regular, Amatuer, or Beginner)
#
# ### Logical (lgl)
# * `subscribe`- Whether the player is subscribed (either TRUE or FALSE)

# %% [markdown]
# ## Sessions Dataset Overview:
# This dataset tracks player's sessions, such as hashed email, start times and end times (one is human-readable, the other is UNIX timestamped).
# * Number of observations (rows): 1535
# * Number of variables (columns): 5
#
#
# ## Columns in the Sessions Data Set:
#
# ### Character (chr):
# * `hashedEmail`- encrypted and anonymous user identification.
# * `start_time`- Session start time (DD/MM/YYYY Hour:Minute)
# * `end_time`- Session end time (DD/MM/YYYY Hour:Minute)
#
# ### Numerical (dbl):
# * `original_start_time`- UNIX timestamp of session start time.
# * `original_end_time`- UNIX timestamp of session end time.

# %% [markdown]
# # Methods and Results
# * Describe the methods you used to perform your analysis from beginning to end that narrates the analysis code

# %%
library(tidyverse)
library(tidymodels)
set.seed(123)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.5.1     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# ── Attaching packages ────────────────────────────────────── tidymodels 1.1.1 ──
#
# ✔ broom        1.0.6     ✔ rsample      1.2.1
# ✔ dials        1.3.0     ✔ tune         1.1.2
# ✔ infer        1.0.7     ✔ workflows    1.1.4
# ✔ modeldata    1.4.0     ✔ workflowsets 1.0.1
# ✔ parsnip      1.2.1     ✔ yardstick    1.3.1
# ✔ recipes      1.1.0
#
# ── Conflicts ───────────────────────────────────────── tidymodels_conflicts() ──
# ✖ scales::discard() masks purrr::discard()
# ✖ dplyr::filter()   masks stats::filter()
# ✖ recipes::fixed()  masks stringr::fixed()
# ✖ dplyr::lag()      masks stats::lag()
# ✖ yardstick::spec() masks readr::spec()
# ✖ recipes::step()   masks stats::step()
# • Use tidymodels_prefer() to resolve common conflicts.

# %%
url<- "https://drive.google.com/uc?export=download&id=1QRsHcWfUyvOWJpKgwFCw3csjRN5NL1L3"
sessions<- read_csv(url)
head(sessions)
# Out:
# Rows: 1535 Columns: 5
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): hashedEmail, start_time, end_time
# dbl (2): original_start_time, original_end_time
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   hashedEmail
# 1 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 2 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 3 f8f5477f5a2e53616ae37421b1c660b971192bd8ff77e3398304c7ae42581fdc
# 4 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
# 5 36d9cbb4c6bc0c1a6911436d2da0d09ec625e43e6552f575d4acc9cf487c4686
# 6 bfce39c89d6549f2bb94d8064d3ce69dc3d7e72b38f431d8aa0c4bf95ccee6bf
#   start_time       end_time         original_start_time original_end_time
# 1 30/06/2024 18:12 30/06/2024 18:24 1.71977e+12         1.71977e+12
# 2 17/06/2024 23:33 17/06/2024 23:46 1.71867e+12         1.71867e+12
# 3 25/07/2024 17:34 25/07/2024 17:57 1.72193e+12         1.72193e+12
# 4 25/07/2024 03:22 25/07/2024 03:58 1.72188e+12         1.72188e+12
# 5 25/05/2024 16:01 25/05/2024 16:12 1.71665e+12         1.71665e+12
# 6 23/06/2024 15:08 23/06/2024 17:10 1.71916e+12         1.71916e+12

# %%
url<- "https://drive.google.com/uc?export=download&id=1jv3p3Ai0a1pNS-hk7csk1I9l21fYy-_t"
players<-read_csv(url)
head(players)
# Out:
# Rows: 196 Columns: 7
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): experience, hashedEmail, name, gender
# dbl (2): played_hours, Age
# lgl (1): subscribe
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   experience subscribe
# 1 Pro         TRUE
# 2 Veteran     TRUE
# 3 Veteran    FALSE
# 4 Amateur     TRUE
# 5 Regular     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 f6daba428a5e19a3d47574858c13550499be23603422e6a0ee9728f8b53e192d 30.3
# 2 f3c813577c458ba0dfef80996f8f32c93b6e8af1fa939732842f2312358a88e9  3.8
# 3 b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3c5a9d2118eb7ccbb28  0.0
# 4 23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4fa7a5a659ff443a0eb5  0.7
# 5 7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb0af4d48fcce2420f3e  0.1
# 6 f58aad5996a435f16b0284a3b267f973f9af99e7a89bee0430055a44fa92f977  0.0
#   name      gender Age
# 1 Morgan    Male    9
# 2 Christian Male   17
# 3 Blake     Male   17
# 4 Flora     Female 21
# 5 Kylie     Male   21
# 6 Adrian    Female 17

# %% [markdown]
# We will convert `played_hours` to `played_minutes` because some of the played hours are very low and close to zero. This would affect our analysis.

# %%
players<- players|>
mutate(played_minutes= (played_hours*60))

# %%
set.seed(123)
players_split<- initial_split(players, prop=0.70, strata= played_minutes)
players_train<- training(players_split)
players_test<- testing(players_split)

# %% [markdown]
# * Set the randomized seed.
# * Split the data into testing and training.
# * Use the proportion of 70% training and 30% testing.

# %%
players_train <- players_train|>
mutate(played_minutes= (played_hours*60))

# %% [markdown]
# Use `summarise` to find the mean played hours, played minutes, and age from the training set. We removed missing values from the dataset using the function `na.rm=TRUE`

# %%
mean_values<- players_train|>
summarise(
    mean_played_hours= mean(played_hours, na.rm=TRUE),
    mean_played_minutes=mean(played_minutes, na.rm=TRUE),
    mean_age= mean(Age, na.rm=TRUE))
mean_values
# Out:
#   mean_played_hours mean_played_minutes mean_age
# 1 6.684559          401.0735            20.26119

# %% [markdown]
# Compute the summary statistics of the `players_train` data set.

# %%
Summary_statistics_players <- players_train|>
summarise(
    min_played_hours= min(played_hours, na.rm=TRUE),
    min_played_minutes= min(played_minutes, na.rm=TRUE),
    min_age= min(Age, na.rm=TRUE),
    max_played_hours= max(played_hours, na.rm=TRUE),
    max_played_minutes=max(played_minutes, na.rm=TRUE),
   max_age= max(Age, na.rm=TRUE))
Summary_statistics_players
# Out:
#   min_played_hours min_played_minutes min_age max_played_hours
# 1 0                0                  8       223.1
#   max_played_minutes max_age
# 1 13386              50

# %%
players_train<- players_train|>
drop_na(Age, played_hours, played_minutes)
head(players_train)
# Out:
#   experience subscribe
# 1 Regular     TRUE
# 2 Amateur    FALSE
# 3 Amateur     TRUE
# 4 Veteran     TRUE
# 5 Pro         TRUE
# 6 Veteran     TRUE
#   hashedEmail                                                      played_hours
# 1 8e594b8953193b26f498db95a508b03c6fe1c24bb5251d392c18a0da9a722807 0.0
# 2 1d2371d8a35c8831034b25bda8764539ab7db0f63938696917c447128a2540dd 0.0
# 3 8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1 0.1
# 4 bbe2d83de678f519c4b3daa7265e683b4fe2d814077f9094afd11d8f217039ec 0.0
# 5 4caa42e1b20511552434978171dcf7283fb6eb857eb871327e39bfc328002309 0.0
# 6 6f9acf8ea9956fe817895c78d10e1e25c11aba335a451e5b0322b073ee5008c4 0.0
#   name    gender     Age played_minutes
# 1 Luna    Female     19  0
# 2 Emerson Male       21  0
# 3 Natalie Male       17  6
# 4 Nyla    Female     22  0
# 5 Daniela Male       17  0
# 6 Niamh   Non-binary 17  0

# %%
players_filtered<- filter(players_train, Age<30, played_hours>0 & played_hours<10)
head(players_filtered)
# Out:
#   experience subscribe
# 1 Amateur     TRUE
# 2 Veteran    FALSE
# 3 Amateur     TRUE
# 4 Veteran     TRUE
# 5 Veteran     TRUE
# 6 Amateur     TRUE
#   hashedEmail                                                      played_hours
# 1 8b71f4d66a38389b7528bb38ba6eb71157733df7d1740371852a797ae97d82d1 0.1
# 2 951e54f7376e2b2f0915e9e3646c701af4a2fe839385b13f9e0084b08f8070bd 0.1
# 3 710148466b44cb02ba894aa9005a4892e619250ebd01153055d6c7578fc1ea10 0.1
# 4 d07befbac08be3d876d026ac0458651067001b39081d24724af3c95be76355e0 0.1
# 5 577aa5f15468252b1c6f32dcd515012923476292e30f95e6b4128c770e993f92 0.1
# 6 7c0ae28a5f85a515a8063f9ed989aa26c5ebcc64f6b7be2948c0b300c2c9bd47 0.1
#   name       gender     Age played_minutes
# 1 Natalie    Male       17  6
# 2 Vivienne   Male       18  6
# 3 Ayman      Male       23  6
# 4 Yvette     Non-binary 17  6
# 5 Winston    Male       17  6
# 6 Evangeline Male       23  6

# %% [markdown]
# Visualize the relationship between Minecraft user age and played minutes in a scatter plot. The scatter plot did not have a linear relationship, therefore we did not use linear regression. We thought that KNN regression was more suitable. This data does not have a clear relationship, which suggests that the KNN regression may not be very accurate or predictive.

# %%
Minecraft_plot<- players_train|>
ggplot(aes(x=Age, y=played_minutes))+
geom_point()+
xlab("Age of Players")+
ylab("Minutes Played Minecraft")+
theme(text=element_text(size=13))+
ggtitle("Relationship Between Minecraft User Age and Minutes Played")
Minecraft_plot
# Out:
# plot without title

# %%
players_recipe<- recipe(played_minutes~ Age, data=players_train)|>
step_scale(all_predictors())|>
step_center(all_predictors())

players_spec<- nearest_neighbor(weight_func= "rectangular", neighbors=tune())|>
set_engine("kknn")|>
set_mode("regression")

# %%
set.seed(123)
players_vfold<- vfold_cv(players_train, v=7, strata= Age)

# %%
players_wkflw<- workflow()|>
add_recipe(players_recipe)|>
add_model(players_spec)
players_wkflw
# Out:
# ══ Workflow ════════════════════════════════════════════════════════════════════
# Preprocessor: Recipe
# Model: nearest_neighbor()
#
# ── Preprocessor ────────────────────────────────────────────────────────────────
# 2 Recipe Steps
#
# • step_scale()
# • step_center()
#
# ── Model ───────────────────────────────────────────────────────────────────────
# K-Nearest Neighbor Model Specification (regression)
#
# Main Arguments:
#   neighbors = tune()
#   weight_func = rectangular
#
# Computational engine: kknn

# %%
gridvals<- tibble(neighbors=seq(from=1, to=20, by=3))

# %%
players_results<- players_wkflw|>
tune_grid(resamples= players_vfold, grid=gridvals)|>
collect_metrics()|>
filter(.metric== "rmse")
players_results


players_min <- players_results|> arrange(mean) 
players_min 
#smallest RMSPE occurs when K=1
# Out:
#   neighbors .metric .estimator mean      n std_err  .config
# 1  1        rmse    standard    995.8162 7 425.6632 Preprocessor1_Model1
# 2  4        rmse    standard   1115.9189 7 394.0146 Preprocessor1_Model2
# 3  7        rmse    standard   1110.9957 7 381.1904 Preprocessor1_Model3
# 4 10        rmse    standard   1052.7552 7 399.5371 Preprocessor1_Model4
# 5 13        rmse    standard   1027.3520 7 401.1414 Preprocessor1_Model5
# 6 16        rmse    standard   1202.7377 7 356.9940 Preprocessor1_Model6
# 7 19        rmse    standard   1065.5144 7 399.1575 Preprocessor1_Model7
#   neighbors .metric .estimator mean      n std_err  .config
# 1  1        rmse    standard    995.8162 7 425.6632 Preprocessor1_Model1
# 2 13        rmse    standard   1027.3520 7 401.1414 Preprocessor1_Model5
# 3 10        rmse    standard   1052.7552 7 399.5371 Preprocessor1_Model4
# 4 19        rmse    standard   1065.5144 7 399.1575 Preprocessor1_Model7
# 5  7        rmse    standard   1110.9957 7 381.1904 Preprocessor1_Model3
# 6  4        rmse    standard   1115.9189 7 394.0146 Preprocessor1_Model2
# 7 16        rmse    standard   1202.7377 7 356.9940 Preprocessor1_Model6

# %% [markdown]
# We will evaluate how well the model is predicting unseen data and evaluate its RMSPE on the test data. We will retrain the KNN regression model on the entire training set using K=10.
# * From the kmin function, I found that the lowest K value is 1. However, a neighbor of 1 would overfit the data so I chose the second best K value. I chose K=10 because it is the second lowest RMSPE value.
#
# Then use `predict` to make predictions on the test data and use the `metrics` function to compute the summary of the regression quality. We specified regression with `set_mode`

# %%
kmin<- players_min|>
pull(neighbors)

# %%
players_spec<- nearest_neighbor(weight_func = "rectangular", neighbors = 10) |>
set_engine("kknn") |>
set_mode("regression")

# %% [markdown]
# From the `kmin` function, I found that the lowest K value is 1. However, a neighbor of 1 would overfit the data so I chose the second best K value. I chose K=10 because it is the second lowest RMSPE value.

# %%
players_fit<- workflow()|>
add_recipe(players_recipe)|>
add_model(players_spec)|>
fit(data=players_train)

players_test = players_test |> filter(!is.na(Age),!is.na(played_minutes))

# %%
players_summary<- players_fit|>
predict(players_test) |>
bind_cols(players_test)|>
metrics(truth=Age, estimate= .pred)|>
filter(.metric=="rmse")
players_summary
# Out:
#   .metric .estimator .estimate
# 1 rmse    standard   459.4988

# %% [markdown]
# The final model's test error is 376.2. Thus the error in our model is roughly 376.2. In this application, the RMSPE is large and suggests that our model is not the best at making predictions.

# %% [markdown]
# This next plot shows the predictions that our final model makes across the range of Ages in the Minecraft playcraft.

# %%
players_prediction_grid<- tibble(
    Age=seq(
                from = players_train |> select(Age) |> min(),
        to = players |> select(Age) |> max(na.rm=TRUE),
        by = 10))

# %%
players_preds <- players_fit |>
  predict(players_prediction_grid) |>
  bind_cols(players_prediction_grid)

# %%
plot_final <- ggplot(players_train, aes(x = Age, y = played_minutes)) +
  geom_point(alpha = 0.4) +
  geom_line(data = players_preds,
            mapping = aes(x = Age, y = .pred),
            color = "steelblue",
            linewidth = 1) +
  xlab("Player Age") +
  ylab("Played Minutes") +
  scale_y_continuous(labels = dollar_format()) +
  ggtitle(paste0("K = 10", kmin)) +
  theme(text = element_text(size = 12))

plot_final
# Out:
# plot without title

# %% [markdown]
# ## Discussion:
# * summarize what you found
# * discuss whether this is what you expected to find?
# * discuss what impact could such findings have?
# * discuss what future questions could this lead to?
